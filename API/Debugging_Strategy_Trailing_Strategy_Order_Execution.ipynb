# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Debugging" data-toc-modified-id="Debugging-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Debugging</a></span></li><li><span><a href="#Entry-price" data-toc-modified-id="Entry-price-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Entry price</a></span></li><li><span><a href="#Position-value" data-toc-modified-id="Position-value-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Position value</a></span></li><li><span><a href="#Margin-available" data-toc-modified-id="Margin-available-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Margin available</a></span></li></ul></div>

# %% [markdown]
# # Debugging
#
#
#     %debug func(*args)           # line magic
#     ipdb> s                      # step into func
#     ipdb> b line_num             # set breakpoint
#     ipdb> c                      # continue until breakpoint
#     ipdb> b                      # list all breakpoint
#     ipdb> clear breakpoint_num   # remove breakpoint_num
#     ipdb> c                      # continue untill function finishes
#     ipdb> u line_num             # run until line_num
#     ipdb> q                      # quit debugger
#
# <u>**To debug on a specific date**</u>:
#
# ```
# class DummyStrategy(Strategy):
#
#     def init(self):
#         pass
#
#     def next(self):
#         if self.data.index[-1] == pd.Timestamp('2019-10-18'):
#             breakpoint()
# ```

# %%
from backtesting import Backtest, Strategy
from backtesting.lib import crossover, SignalStrategy, TrailingStrategy
from backtesting.test import SMA

import pandas_datareader.data as dtr
import requests_cache
import datetime
expire_after = datetime.timedelta(days = 7)
session = requests_cache.CachedSession(cache_name='cache', backend='sqlite',
                                       expire_after=expire_after)

tickers = ["LNTA.ME", "MTSS.ME","GAZP.ME","CHMF.ME","SBER.ME"]

df = pd.DataFrame()
for ticker in tickers:
    try:
        df_ = dtr.DataReader(ticker, data_source="yahoo" , session=session, retry_count=1)
        df_.insert(0, "ticker", ticker)
    except:
        print(f"ticker '{ticker}' failed")
        pass
    df = df.append(df_)

GAZP = df[df.ticker == "GAZP.ME"]
GAZP.head()
# Out:
# /home/sergey/anaconda3/lib/python3.7/site-packages/backtesting/_plotting.py:45: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#              ticker        High         Low        Open       Close  \
# Date
# 2015-12-21  GAZP.ME  133.940002  131.000000  132.000000  131.500000
# 2015-12-22  GAZP.ME  133.539993  131.809998  132.000000  133.199997
# 2015-12-23  GAZP.ME  135.300003  133.350006  133.550003  135.300003
# 2015-12-24  GAZP.ME  138.080002  134.449997  135.850006  136.000000
# 2015-12-25  GAZP.ME  136.490005  134.029999  136.490005  134.479996
#
#                 Volume   Adj Close
# Date
# 2015-12-21  28393100.0  131.500000
# 2015-12-22  20022420.0  133.199997
# 2015-12-23  26760910.0  135.300003
# 2015-12-24  36828650.0  136.000000
# 2015-12-25  14866310.0  134.479996

# %%
class SmaSignalTrailing(SignalStrategy, TrailingStrategy):
    
    n_fast = 24
    n_slow = 55
    trailing_sl = 3
    sz = .95
    

    def init(self):
        super().init()
        nfast = self.I(SMA, self.data.Close, self.n_fast)
        nslow = self.I(SMA, self.data.Close, self.n_slow)
        signal = (pd.Series(nfast) > nslow).astype(int).diff().fillna(0)
        signal = signal.replace(-1,0)
        self.set_signal(entry_size = self.sz*signal)
        self.set_trailing_sl(self.trailing_sl)
        
bt = Backtest(GAZP, SmaSignalTrailing, commission=.002,margin=.5)

# %% [markdown]
# # Entry price
#
# >    - `self._data.Open[-1]*1.002` or,
# >    - if trade on close `self.last_price`, which is `self._data.Close[-2]`,
# >    - multiplied by `1 + commisions` for long and `1 - commisions` for short
# >
# # Position value
#
# >    - `self.trades[0].size * self.last_price`
# >
# # Margin available
#
# >    - available cash is stored in `self.margin_available`
# >    - calsulated as:
# >        - `self.equity - (self.trades[0].value / self._leverage)`
# >        - equity is: `self._cash + self.trades[0].pl`

# %%
# %%debug
# bt.run()
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(2)<module>()
#
# ipdb> s
# --Call--
# > /home/sergey/anaconda3/lib/python3.7/site-packages/backtesting/backtesting.py(1088)run()
#    1086         self._results = None
#    1087
# -> 1088     def run(self, **kwargs) -> pd.Series:
#    1089         """
#    1090         Run the backtest. Returns `pd.Series` with results and statistics.
#
# ipdb> b 853
# Breakpoint 1 at /home/sergey/anaconda3/lib/python3.7/site-packages/backtesting/backtesting.py:853
# ipdb> c
# > /home/sergey/anaconda3/lib/python3.7/site-packages/backtesting/backtesting.py(853)_process_orders()
#     851             # precompute true size in units, accounting for margin and spread/commissions
#     852             size = order.size
# 1-> 853             if -1 < size < 1:
#     854                 #breakpoint()
#     855                 size = copysign(int((self.margin_available * self._leverage * abs(size))
#
# ipdb> self._data.Open[-1]*1.002
# 136.4423381652832
# ipdb> self.equity
# 10000
# ipdb> dir(self)
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adjusted_price', '_cash', '_close_trade', '_commission', '_data', '_equity', '_exclusive_orders', '_hedging', '_i', '_leverage', '_open_trade', '_process_orders', '_reduce_trade', '_trade_on_close', 'closed_trades', 'equity', 'last_price', 'margin_available', 'new_order', 'next', 'orders', 'position', 'trades']
# ipdb> self.margin_available
# 10000
# ipdb> c
# > /home/sergey/anaconda3/lib/python3.7/site-packages/backtesting/backtesting.py(853)_process_orders()
#     851             # precompute true size in units, accounting for margin and spread/commissions
#     852             size = order.size
# 1-> 853             if -1 < size < 1:
#     854                 #breakpoint()
#     855                 size = copysign(int((self.margin_available * self._leverage * abs(size))
#
# ipdb> self.margin_available
# 1155.1046556701676
# ipdb> self.trades[0]
# <Trade size=139 time=200- price=136.4423381652832- pl=1276>
# ipdb> 10000 - 139*self.trades[0].price
# *** AttributeError: 'Trade' object has no attribute 'price'
# ipdb> self.trades[0].pl
# 1275.694316314699
# ipdb> self.trades[0].price
# *** AttributeError: 'Trade' object has no attribute 'price'
# ipdb> dir(self.trades)
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ipdb> dir(self.trades[0])
# ['_Trade__broker', '_Trade__entry_bar', '_Trade__entry_price', '_Trade__exit_bar', '_Trade__exit_price', '_Trade__set_contingent', '_Trade__size', '_Trade__sl_order', '_Trade__tp_order', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_copy', '_replace', '_sl_order', '_tp_order', 'close', 'entry_bar', 'entry_price', 'entry_time', 'exit_bar', 'exit_price', 'exit_time', 'is_long', 'is_short', 'pl', 'pl_pct', 'size', 'sl', 'tp', 'value']
# ipdb> 10000 - 139*self.trades[0].entry_price
# -8965.485004974362
# ipdb> 10000*2 - 139*self.trades[0].entry_price
# 1034.5149950256382
# ipdb> self.available_margin
# *** AttributeError: '_Broker' object has no attribute 'available_margin'
# ipdb> dir(self)
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adjusted_price', '_cash', '_close_trade', '_commission', '_data', '_equity', '_exclusive_orders', '_hedging', '_i', '_leverage', '_open_trade', '_process_orders', '_reduce_trade', '_trade_on_close', 'closed_trades', 'equity', 'last_price', 'margin_available', 'new_order', 'next', 'orders', 'position', 'trades']
# ipdb> 2*(10000*2 - 139*self.trades[0].entry_price)
# 2069.0299900512764
# ipdb> self.margin_available
# 1155.1046556701676
# ipdb> 10000*2 - 139*self.trades[0].entry_price
# 1034.5149950256382
# ipdb> self.margin_available*2/(self._data.Open[-1]*1.002)
# 16.70723271818924
# ipdb> .95*self.margin_available*2/(self._data.Open[-1]*1.002)
# 15.871871082279775
# ipdb> self.margin_available
# 1155.1046556701676
# ipdb> self.last_price
# 145.6199951171875
# ipdb> self.margin_available
# 1155.1046556701676
# ipdb> self.equity
# 11275.694316314699
# ipdb> self.trades[0].value
# 20241.179321289062
# ipdb> dir(self.trades[0])
# ['_Trade__broker', '_Trade__entry_bar', '_Trade__entry_price', '_Trade__exit_bar', '_Trade__exit_price', '_Trade__set_contingent', '_Trade__size', '_Trade__sl_order', '_Trade__tp_order', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_copy', '_replace', '_sl_order', '_tp_order', 'close', 'entry_bar', 'entry_price', 'entry_time', 'exit_bar', 'exit_price', 'exit_time', 'is_long', 'is_short', 'pl', 'pl_pct', 'size', 'sl', 'tp', 'value']
# ipdb> size.trades[0].value
# *** AttributeError: 'float' object has no attribute 'trades'
# ipdb> self._trades[0].values
# *** AttributeError: '_Broker' object has no attribute '_trades'
# ipdb> self.trades[0].value
# 20241.179321289062
# ipdb> self.trades[0].entry_price * self.trades[0].size
# 18965.48500497436
# ipdb> self.trades[0].value - self.trades[0].entry_price * self.trades[0].size
# 1275.6943163147007
# ipdb> self.trades[0].pl
# 1275.694316314699
# ipdb> self.trades[0].size*(-self.trades[0].entry_price + self.last_price)
# 1275.694316314699
# ipdb> self.trades[0].value
# 20241.179321289062
# ipdb> self.trades[0].size * self.trades[0].last_price
# *** AttributeError: 'Trade' object has no attribute 'last_price'
# ipdb> self.trades[0].size * self.last_price
# 20241.179321289062
# ipdb> self.trades[0].pl
# 1275.694316314699
# ipdb> self.trades[0].value - self.trades[0].entry_price*self.trades[0].size
# 1275.6943163147007
# ipdb> self.trades[0].size*self.last_price - self.trades[0].entry_price*self.trades[0].size
# 1275.6943163147007
# ipdb> self.trades[0].size*(self.last_price - self.trades[0].entry_price)
# 1275.694316314699
# ipdb> self.trades[0].pl
# 1275.694316314699
# ipdb> self.equity
# 11275.694316314699
# ipdb> self.cash
# *** AttributeError: '_Broker' object has no attribute 'cash'
# ipdb> self._cash
# 10000
# ipdb> self._cash + self.trades[0].pl
# 11275.694316314699
# ipdb> self.equity
# 11275.694316314699
# ipdb> dir(self)
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adjusted_price', '_cash', '_close_trade', '_commission', '_data', '_equity', '_exclusive_orders', '_hedging', '_i', '_leverage', '_open_trade', '_process_orders', '_reduce_trade', '_trade_on_close', 'closed_trades', 'equity', 'last_price', 'margin_available', 'new_order', 'next', 'orders', 'position', 'trades']
# ipdb> self.trades[0].value/.5
# 40482.358642578125
# ipdb> self.trades[0].value*.5
# 10120.589660644531
# ipdb> self.trades[0].value/self._leverage
# 10120.589660644531
# ipdb> self.trades[0].value
# 20241.179321289062
# ipdb> self.trades[0].size * self.last_price
# 20241.179321289062
# ipdb> self.margin_available
# 1155.1046556701676
# ipdb> self.equity - (self.trades[0].value * self.leverage)
# *** AttributeError: '_Broker' object has no attribute 'leverage'
# ipdb> dir(self)
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adjusted_price', '_cash', '_close_trade', '_commission', '_data', '_equity', '_exclusive_orders', '_hedging', '_i', '_leverage', '_open_trade', '_process_orders', '_reduce_trade', '_trade_on_close', 'closed_trades', 'equity', 'last_price', 'margin_available', 'new_order', 'next', 'orders', 'position', 'trades']
# ipdb> self.equity - (self.trades[0].value * self._leverage)
# -29206.664326263424
# ipdb> self.equity - (self.trades[0].value / self.leverage)
# *** AttributeError: '_Broker' object has no attribute 'leverage'
# ipdb> self.equity - (self.trades[0].value / self._leverage)
# 1155.1046556701676
# ipdb> self.margin_available
# 1155.1046556701676
# ipdb> q

# %%
stats = bt.run()
stats._trades.sort_values("EntryTime")
# Out:
#     Size  EntryBar  ExitBar  EntryPrice   ExitPrice           PnL  ReturnPct  \
# 1    139       200      285  136.442338  146.646100   1418.322896   0.074784
# 0     15       221      285  138.276000  146.646100    125.551500   0.060532
# 4    178       354      535  122.845198  138.046109   2705.762103   0.123740
# 3      2       403      535  117.053640  138.046109     41.984939   0.179341
# 2      7       443      535  123.496500  138.046109    101.847264   0.117814
# 5    187       583      621  145.490397  138.676099  -1274.273755  -0.046837
# 7    175       658      710  141.632706  159.806104   3180.344572   0.128314
# 6     12       671      710  141.783000  159.806104    216.277244   0.127118
# 9    207       759      795  151.302000  153.096097    371.378070   0.011858
# 8     24       778      795  160.420206  153.096097   -175.778620  -0.045656
# 10   194       836      893  163.536427  243.046109  15424.878392   0.486189
# 12   264       942      978  231.211500  258.436093   7187.292629   0.117748
# 11    39       971      978  262.774500  258.436093   -169.197862  -0.016510
# 13   405      1102     1122  183.596456  195.696103   4900.357172   0.065903
# 14   451      1240     1254  185.500265  214.000000  12853.380533   0.153637
#
#     EntryTime   ExitTime Duration
# 1  2016-10-10 2017-02-08 121 days
# 0  2016-11-09 2017-02-08  91 days
# 4  2017-05-23 2018-02-08 261 days
# 3  2017-08-01 2018-02-08 191 days
# 2  2017-09-26 2018-02-08 135 days
# 5  2018-04-19 2018-06-15  57 days
# 7  2018-08-07 2018-10-18  72 days
# 6  2018-08-24 2018-10-18  55 days
# 9  2018-12-27 2019-02-21  56 days
# 8  2019-01-29 2019-02-21  23 days
# 10 2019-04-22 2019-07-15  84 days
# 12 2019-09-20 2019-11-12  53 days
# 11 2019-10-31 2019-11-12  12 days
# 13 2020-05-14 2020-06-11  28 days
# 14 2020-11-30 2020-12-18  18 days

# %%
GAZP["2016-11"]
# Out:
#              ticker        High         Low        Open       Close  \
# Date
# 2016-11-01  GAZP.ME  142.440002  139.009995  139.119995  141.979996
# 2016-11-02  GAZP.ME  143.639999  140.029999  141.490005  140.809998
# 2016-11-03  GAZP.ME  141.300003  139.300003  140.500000  139.899994
# 2016-11-07  GAZP.ME  140.960007  138.500000  140.500000  138.500000
# 2016-11-08  GAZP.ME  140.979996  138.809998  138.860001  139.320007
# 2016-11-09  GAZP.ME  145.619995  137.550003  138.000000  145.619995
# 2016-11-10  GAZP.ME  151.300003  145.750000  146.449997  147.399994
# 2016-11-11  GAZP.ME  149.500000  145.789993  147.399994  147.880005
# 2016-11-14  GAZP.ME  149.669998  145.960007  148.600006  146.259995
# 2016-11-15  GAZP.ME  148.000000  145.600006  146.500000  145.899994
# 2016-11-16  GAZP.ME  148.800003  145.139999  147.070007  145.500000
# 2016-11-17  GAZP.ME  147.779999  145.320007  145.820007  147.699997
# 2016-11-18  GAZP.ME  148.289993  146.740005  147.509995  146.960007
# 2016-11-21  GAZP.ME  149.850006  147.600006  147.600006  149.600006
# 2016-11-22  GAZP.ME  150.830002  149.059998  150.199997  150.000000
# 2016-11-23  GAZP.ME  150.380005  148.559998  150.240005  149.490005
# 2016-11-24  GAZP.ME  152.250000  149.350006  149.529999  151.110001
# 2016-11-25  GAZP.ME  151.600006  149.500000  150.940002  151.309998
# 2016-11-28  GAZP.ME  151.479996  148.389999  151.179993  148.940002
# 2016-11-29  GAZP.ME  149.490005  147.339996  148.830002  147.750000
# 2016-11-30  GAZP.ME  151.119995  147.600006  148.000000  148.800003
#
#                  Volume   Adj Close
# Date
# 2016-11-01   49424750.0  141.979996
# 2016-11-02   43150830.0  140.809998
# 2016-11-03   24879410.0  139.899994
# 2016-11-07   23567564.0  138.500000
# 2016-11-08   20844700.0  139.320007
# 2016-11-09   79385300.0  145.619995
# 2016-11-10  103218470.0  147.399994
# 2016-11-11   45422659.0  147.880005
# 2016-11-14   31655630.0  146.259995
# 2016-11-15   23781520.0  145.899994
# 2016-11-16   40902380.0  145.500000
# 2016-11-17   28348942.0  147.699997
# 2016-11-18   14649260.0  146.960007
# 2016-11-21   26159041.0  149.600006
# 2016-11-22   26583950.0  150.000000
# 2016-11-23   19329900.0  149.490005
# 2016-11-24   26216005.0  151.110001
# 2016-11-25   17904148.0  151.309998
# 2016-11-28   24402370.0  148.940002
# 2016-11-29   21155780.0  147.750000
# 2016-11-30   44343200.0  148.800003
